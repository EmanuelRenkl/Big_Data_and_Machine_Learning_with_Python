# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.DataFrame({"name": ["Johanna", "Alex", "Dennis", "Maripjan", "Liza", "Michael"],
                  "age": [27, 24, 29, 23, 23, 30], 
                  "gender": ["f", "m", "m", "m", "f", "m"], 
                  'citizenship':["ger","per","ger","kg","rus","ger"],
                  'years_academia':[1,1,3,-1,-1,5]
                  })

# %%
print(df.shape)
# Out:
# (6, 5)

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of        name  age gender citizenship  years_academia
# 0   Johanna   27      f         ger               1
# 1      Alex   24      m         per               1
# 2    Dennis   29      m         ger               3
# 3  Maripjan   23      m          kg              -1
# 4      Liza   23      f         rus              -1
# 5   Michael   30      m         ger               5>

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of        name  age gender citizenship  years_academia
# 0   Johanna   27      f         ger               1
# 1      Alex   24      m         per               1
# 2    Dennis   29      m         ger               3
# 3  Maripjan   23      m          kg              -1
# 4      Liza   23      f         rus              -1
# 5   Michael   30      m         ger               5>

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of        name  age gender citizenship  years_academia
# 0   Johanna   27      f         ger               1
# 1      Alex   24      m         per               1
# 2    Dennis   29      m         ger               3
# 3  Maripjan   23      m          kg              -1
# 4      Liza   23      f         rus              -1
# 5   Michael   30      m         ger               5>

# %%
df.plot.scatter(x="age", y ="years_academia")

# %%
df.plot.bar(x="name",y="age")

# %%
df.plot.line(x="name", y="years_academia")

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
df.plot.line(x='name',y='years_academia',ax=ax)
ax.set_title("Example")
plt.legend(loc='center left', title = 'legend')

# %%
plt.savefig("TEST.pdf")

# %%
grouped = df.groupby(['citizenship','gender'])['name'].size().unstack()

# %%
print(grouped)
# Out:
# gender         f    m
# citizenship
# ger          1.0  2.0
# kg           NaN  1.0
# per          NaN  1.0
# rus          1.0  NaN

# %%
grouped.plot.bar(stacked=True)

# %%
grouped.T.plot.bar(stacked=True)

# %%
grouped.plot.barh(stacked=True)
