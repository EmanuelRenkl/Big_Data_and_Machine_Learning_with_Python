# %%
# Load the data from ./data/drink.csv into a DataFrame. The data is on 
# country’s alcoholic consumption.

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


FNAME = "01_Data/drinks.csv"
df = pd.read_csv(FNAME, sep = ',')
df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9       NaN
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3       NaN
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3       NaN
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8       NaN
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4       NaN
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7       NaN
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# Which continent drinks most beer on average?

grouped = df.groupby(["continent"])
print(grouped["beer_servings"].mean()) # EU drinks most beer on average
# Out:
# continent
# AF     61.471698
# AS     37.045455
# EU    193.777778
# OC     89.687500
# SA    175.083333
# Name: beer_servings, dtype: float64

# %%
# Which continent drinks most wine on average? 

print(grouped["wine_servings"].mean()) # EU drinks most wine on average
# Out:
# continent
# AF     16.264151
# AS      9.068182
# EU    142.222222
# OC     35.625000
# SA     62.416667
# Name: wine_servings, dtype: float64

# %%
#  Create a Boxenplot of ”beer servings” by continent.

fig = sns.catplot(x = "continent", y = "beer_servings", data = df)

# %%
df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# 12                Bahrain             42               63              7
# 13             Bangladesh              0                0              0
# 14               Barbados            143              173             36
# 15                Belarus            142              373             42
# 16                Belgium            295               84            212
# 17                 Belize            263              114              8
# 18                  Benin             34                4             13
# 19                 Bhutan             23                0              0
# 20                Bolivia            167               41              8
# 21     Bosnia-Herzegovina             76              173              8
# 22               Botswana            173               35             35
# 23                 Brazil            245              145             16
# 24                 Brunei             31                2              1
# 25               Bulgaria            231              252             94
# 26           Burkina Faso             25                7              7
# 27                Burundi             88                0              0
# 28          Cote d'Ivoire             37                1              7
# 29             Cabo Verde            144               56             16
# ..                    ...            ...              ...            ...
# 163              Suriname            128              178              7
# 164             Swaziland             90                2              2
# 165                Sweden            152               60            186
# 166           Switzerland            185              100            280
# 167                 Syria              5               35             16
# 168            Tajikistan              2               15              0
# 169              Thailand             99              258              1
# 170             Macedonia            106               27             86
# 171           Timor-Leste              1                1              4
# 172                  Togo             36                2             19
# 173                 Tonga             36               21              5
# 174     Trinidad & Tobago            197              156              7
# 175               Tunisia             51                3             20
# 176                Turkey             51               22              7
# 177          Turkmenistan             19               71             32
# 178                Tuvalu              6               41              9
# 179                Uganda             45                9              0
# 180               Ukraine            206              237             45
# 181  United Arab Emirates             16              135              5
# 182        United Kingdom            219              126            195
# 183              Tanzania             36                6              1
# 184                   USA            249              158             84
# 185               Uruguay            115               35            220
# 186            Uzbekistan             25              101              8
# 187               Vanuatu             21               18             11
# 188             Venezuela            333              100              3
# 189               Vietnam            111                2              1
# 190                 Yemen              6                0              0
# 191                Zambia             32               19              4
# 192              Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9       NaN
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3       NaN
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3       NaN
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8       NaN
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4       NaN
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7       NaN
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %%
# Reshape the data and create a 3x1 figure for ”beer servings”, ”wine 
# servings” and ”spirit servings” by continent (i.e. three boxenplots 
# that share their y-axis and a their color coding).

g = sns.FacetGrid(df, hue="xx", col = "continent")
g = g.map(plt.scatter, "beer servings", "wine servings", "spirit servings")

# Save the figure as ./out/alcohol.pdf

plt.savefig("02_Data/alcohol.pdf")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xx'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-e8b3041cc1ef> in <module>()
#       3 # that share their y-axis and a their color coding).
#       4
# ----> 5 g = sns.FacetGrid(df, hue="xx", col = "continent")
#       6 g = g.map(plt.scatter, "beer servings", "wine servings", "spirit servings")
#       7
#
# /anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     235             hue_names = None
#     236         else:
# --> 237             hue_names = utils.categorical_order(data[hue], hue_order)
#     238
#     239         colors = self._get_palette(data, hue, hue_order, palette)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'xx'
